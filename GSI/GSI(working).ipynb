# %%
import json
import numpy as np
import xobjects as xo
import xtrack as xt
import xpart as xp
from tqdm import tqdm
import matplotlib.pyplot as plt
from scipy import constants 

#references: https://link.springer.com/content/pdf/10.1007/s10751-005-9217-x.pdf?pdf=button
#coasting beam: https://accelconf.web.cern.ch/cool2013/papers/tham1ha04.pdf

# Ion properties:
m_u = 931.49410242e6 # eV/c^2 -- atomic mass unit
A = 12.011 # Weight of C
Z = 6  # Number of protons in the ion (C)
Ne = 3 # Number of remaining electrons (Lithium-like)
m_e = 0.511e6 # eV/c^2 -- electron mass
m_p = 938.272088e6 # eV/c^2 -- proton mass
clight = 299792458.0 # m/s

q0=Z-Ne

mass0 = A*m_u + Ne*m_e # eV/c^2

beta0 = 0.47
gamma0 = 1.13

p0c = mass0*beta0*gamma0 #eV/c

# p0c = equiv_proton_momentum*(Z-Ne) # eV/c
gamma = np.sqrt( 1 + (p0c/mass0)**2 ) # ion relativistic factor
beta = np.sqrt(1-1/(gamma*gamma)) # ion beta

particle_ref = xp.Particles(p0c=p0c, mass0=mass0, q0=q0, gamma=gamma)

# %%
#https://www.sciencedirect.com/science/article/pii/0168583X87905830

#twiss parameters measurments:
# https://accelconf.web.cern.ch/ipac2023/pdf/TUPM095.pdf

circumference =  108.36 #m
T = circumference/(clight*beta0)
s_per_turn = T
turn_per_sec=1/T

beta_x = 5
beta_y = 5

disp_x = 0
qx = 2.21
qy = 2.41
dQx = 0
dQy = 0

voltage_rf =  66.84*1e3 # eV
lag_rf = 0
frequency_rf = 1.29*1e6 # Hz
momentum_compaction_factor = 0.02

# arc = xt.LineSegmentMap(
#         qx=Q_x, qy=Q_y,
#         length=circumference,
#         betx=beta_x,
#         bety=beta_y
#         )

alpha_x=0
alpha_y=0
Dx=0
Dpx=0
Dy=0
Dpy=0

###################################################################
# Given parameters

freq_s = 221  # Synchrotron frequency in Hz
freq_rev=turn_per_sec

# # Step 1: Compute the harmonic number
# h = freq_rf / freq_rev
# print(f"Harmonic number: {h}")

# Step 2: Compute the synchrotron tune
qs = freq_s / freq_rev
print(f"Synchrotron tune (qs): {qs}")

# Step 3: Compute the longitudinal beta function
beta_s = clight / (2 * np.pi * qs * freq_rev)
print(f"Longitudinal beta function (betas): {beta_s} m")

####################################################################


arc_rf = xt.LineSegmentMap(
        qx=qx, qy=qy,
        length=circumference,
        betx=beta_x,
        bety=beta_y,
        
        voltage_rf=voltage_rf,
        lag_rf=lag_rf,
        frequency_rf=frequency_rf,
        momentum_compaction_factor=momentum_compaction_factor,
        longitudinal_mode = 'nonlinear'
        )


arc = xt.LineSegmentMap(
        qx=qx, qy=qy,
        length=circumference,
        betx=beta_x,
        bety=beta_y,
        
        longitudinal_mode = 'linear_fixed_qs',
        qs=0.005267376184480865,
        bets=620.1335945110944
        )

# arc = xt.LineSegmentMap(
#         qx=qx, qy=qy,
#         length=circumference,
#         betx=beta_x,
#         bety=beta_y,
        
#         longitudinal_mode = 'linear_fixed_qs',
#         qs=qs,
#         bets=beta_s
#         )
# Out:
# Synchrotron tune (qs): 0.00016995842943837145
# Longitudinal beta function (betas): 215897.9710061965 m

# %%
emittance=2*1e-6 #inital emittance
num_particles = int(1e3)

sigma_x = np.sqrt(beta_x*emittance)
sigma_px = np.sqrt(emittance*1/beta_x)
sigma_y = np.sqrt(beta_y*emittance)
sigma_py = np.sqrt(emittance*1/beta_y)
sigma_p = 1e-3 # relative ion momentum spread

delta = np.random.normal(loc=0, scale=sigma_p, size=num_particles)

delta = np.random.normal(loc=0.0, scale=sigma_p, size=num_particles)
x = np.random.normal(loc=0.0, scale=sigma_x, size=num_particles) + disp_x * delta
px = np.random.normal(loc=0.0, scale=sigma_px, size=num_particles)
y = np.random.normal(loc=0.0, scale=sigma_y, size=num_particles)
py = np.random.normal(loc=0.0, scale=sigma_py, size=num_particles)


# particles = xp.Particles(
#     mass0=mass0,
#     p0c=p0c,
#     q0=q0,
#     x=0,
#     px=0,
#     y=0,
#     py=0,
#     delta=delta,
#     zeta=0
# )


# particles = xp.Particles(
#     mass0=mass0,
#     p0c=p0c,
#     q0=q0,
#     x=x,
#     px=px,
#     y=y,
#     py=py,
#     delta=delta,
#     zeta=0
# )

# %%
sigma_x*1e3
# Out:
# 3.1622776601683795

# %%
line_arc=xt.Line(
        elements=[arc])
line_arc.build_tracker()
# Out:
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.

# %%
num_particles = int(1e4)

sigma_z=0.6# this gives a rms dp_p =1e-3
# sigma_z=0.3
sigma_z=1000

g_emitt = 2*1e-6
#sigma_dp = 1e-3  # Relative energy spread

nemitt = beta * gamma * g_emitt


particles = xp.generate_matched_gaussian_bunch(
        num_particles=num_particles,
        #total_intensity_particles=bunch_intensity,
        nemitt_x=nemitt, nemitt_y=nemitt, sigma_z=sigma_z,
        particle_ref=particle_ref,
        line=line_arc
        )

particles._init_random_number_generator()

np.std(particles.delta*1e3)
# Out:
# LinkedArrayCpu(4.67160949)

# %%
long_part = xp.generate_longitudinal_coordinates(num_particles=num_particles,
        #total_intensity_particles=bunch_intensity,
        sigma_z=sigma_z,
        particle_ref=particle_ref,
        line=line_arc)

zeta_long,delta_long = long_part

np.std(delta_long*1e3)
# Out:
# 0.002794320934282535

# %%
sigma_dp=np.std(particles.delta)

# %%
sigma_dp*1e3
# Out:
# LinkedArrayCpu(0.95673078)

# %%
##################
# Laser Cooler #
##################

#laser-ion beam collision angle
theta_l = 2.6*np.pi/180 # rad
theta_l = 0
nx = 0; ny = -np.sin(theta_l); nz = -np.cos(theta_l)

# Ion excitation energy:
# hw0 = 230.823 # eV
hc=constants.hbar*clight/constants.e # eV*m (ħc)
lambda_0 = 155.078*1e-9 # m -- ion excitation wavelength
lambda_0 = 154.81 *1e-9


hw0 = 2*np.pi*hc/lambda_0 # m -- ion excitation wavelength
ion_excited_lifetime=3.8e-9 #souce: Combined Laser and Electron Cooling of Bunched C3+ Ion Beams at the Storage Ring ESR

lambda_l = lambda_0*gamma0*(1 + beta0*np.cos(theta_l)) # m -- laser wavelength

# Shift laser wavelength for fast longitudinal cooling:
lambda_l = lambda_l*(1+2*sigma_dp) # m
laser_frequency = clight/lambda_l # Hz

# lambda_l=256*1e-9
print('Laser wavelength Peter = %.2f nm' % (lambda_l/1e-9))
print('Laser wavelength Eidam = 256 nm')
print('------------------------------------------------------------------------------')

# print('laser_frequency Peter = %.2f Hz' % (laser_frequency*1e-9))
# print('laser_frequency Eidam = %.2f Hz' % (laser_frequency*1e-9))

laser_waist_radius = 1.3e-3 #m

sigma_w = 2*np.pi*laser_frequency*sigma_dp/2

#sigma_w = 2*np.pi*laser_frequency*sigma_dp/2# for fast longitudinal cooling

sigma_t = 1/sigma_w # sec -- Fourier-limited laser pulse
sigma_t_eidam=45.8*1e-12
sigma_t_ipac = 2.74 *1e-12
sigma_w_eidam=1/sigma_t_eidam
print('Pulse duration Peter = %.2f ps' % (sigma_t*1e12))
print('Pulse duration Eidam = 45.8 ps')
ratio_pulse_duration = 45.8/sigma_t*1e-12

print('ratio_pulse_duration',ratio_pulse_duration)
laser_energy = 16*1e-9
laser_energy = 16*1e-5

print('IPAC values')
print('-------------------------------------')
print('Pulse duration IPAC  = 2.74 ps')
print('Laser wavelength     = 1031.80 nm')
print('laser_energy         = 0.005')


GF_IP = xt.PulsedLaser(
                laser_direction_nx = 0,
                laser_direction_ny = 0,
                laser_direction_nz = -1,
                laser_energy         = laser_energy, # J
                laser_duration_sigma = sigma_t, # sec
                laser_wavelength = lambda_l, # m
                laser_waist_radius = laser_waist_radius, # m
                laser_waist_shift = 0, # m
                ion_excitation_energy = hw0, # eV
                ion_excited_lifetime  = ion_excited_lifetime, # sec                   
                )


# simulation parameters: simulate 10 s of cooling, and take data once every 100 ms
max_time_s = 10*s_per_turn
int_time_s = 2*s_per_turn
max_time_s = 1
int_time_s = 0.01

T_per_turn = circumference/(clight*beta)
num_turns = int(max_time_s/T_per_turn)
save_interval = int(int_time_s/T_per_turn)


# create a monitor object, to reduce holded data
monitor = xt.ParticlesMonitor(start_at_turn=0, stop_at_turn=1,
                        n_repetitions=int(num_turns/save_interval),
                        repetition_period=save_interval,
                        num_particles=num_particles)
                        
line = xt.Line(
        elements=[GF_IP,monitor,arc])

# line = xt.Line(
#         elements=[monitor,arc])

context = xo.ContextCpu(omp_num_threads=4)
line.build_tracker(_context=context)

line.track(particles, num_turns=num_turns,
        turn_by_turn_monitor=False,with_progress=True)

# extract relevant values
x = monitor.x[:,:,0]
px = monitor.px[:,:,0]
y = monitor.y[:,:,0]
py = monitor.py[:,:,0]
delta = monitor.delta[:,:,0]
zeta = monitor.zeta[:,:,0]
state = monitor.state[:,:,0]
time = monitor.at_turn[:, 0, 0] * T_per_turn

gamma_x=(1+alpha_x**2)/beta_x
gamma_y=(1+alpha_y**2)/beta_y

action_x = (gamma_x*(x-Dx*delta)**2 + 2*alpha_x*(x-Dx*delta)*(px-Dpx*delta)+ beta_x*(px-Dpx*delta)**2)
action_y = (gamma_y*(y-Dy*delta)**2 + 2*alpha_y*(y-Dy*delta)*(py-Dpy*delta)+ beta_y*(py-Dpy*delta)**2)

emittance_x_twiss=np.mean(action_x,axis=1)*gamma/2
rms_dp_p=np.std(delta,axis=1)


np.savez(f'results/GSI.npz', x=x, px=px, y=y, py=py, zeta=zeta, delta=delta,
        action_x=action_x,action_y=action_y,emittance_x=emittance_x_twiss,
        state=state, time=time,s_per_turn=T_per_turn)
# Out:
# Laser wavelength Peter = 257.65 nm
# Laser wavelength Eidam = 256 nm
# ------------------------------------------------------------------------------
# Pulse duration Peter = 0.29 ps
# Pulse duration Eidam = 45.8 ps
# ratio_pulse_duration 160.17723822609608
# IPAC values
# -------------------------------------
# Pulse duration IPAC  = 2.74 ps
# Laser wavelength     = 1031.80 nm
# laser_energy         = 0.005
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Tracking:   0%|          | 0/12977000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[115], line 99
#      96 context = xo.ContextCpu(omp_num_threads=4)
#      97 line.build_tracker(_context=context)
# ---> 99 line.track(particles, num_turns=num_turns,
#     100         turn_by_turn_monitor=False,with_progress=True)
#     102 # extract relevant values
# ...

# %%
excited=state==2
#fraction_excited=sum(excited)/len(excited)
fraction_excited = np.sum(excited, axis=0) / excited.shape[0]

# %%
plt.figure()
plt.plot(fraction_excited)
plt.show()

# %%
plt.figure()
plt.plot(time,rms_dp_p)
plt.show()

# %%
turn=6
excited=state==2
excited0=excited[turn,:]
fraction_excitation0 = sum(excited0)/len(excited0)*100

laser_x=0

plt.figure(figsize=(12, 8))
plt.rcParams.update({'font.size': 25})
plt.title(f'Fraction excited: {round(fraction_excitation0, 1)}%')

# #plt.axvline(laser_x,color='red')
# plt.axvline(laser_x+laser_waist_radius,color='red')
# plt.axvline(laser_x-laser_waist_radius,color='red')

plt.scatter(x[turn],delta[turn])
plt.scatter(x[turn][excited0],delta[turn][excited0])
plt.xlabel('x [mm]')
plt.ylabel('dp/p ')
plt.tight_layout()
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
#plt.savefig('First_turn.eps', format='eps', dpi=300)
plt.show()

# %%
delta
# Out:
# LinkedArrayCpu([[-8.43035856e-05,  1.81553296e-03, -1.14888128e-03, ...,
#                   2.48908892e-04,  4.83743750e-04,  3.54733666e-04],
#                 [-4.92682345e-04, -1.36349621e-03, -3.61020253e-04, ...,
#                   1.33136532e-03, -5.43151608e-04, -1.38364019e-03],
#                 [ 6.59762221e-04, -2.19487347e-04,  1.56899271e-03, ...,
#                  -1.80502492e-03,  1.51898206e-04,  1.26215156e-03],
#                 ...,
#                 [-9.47259486e-05, -3.15708132e-04,  2.83688377e-04, ...,
#                   2.64487734e-05, -2.19637700e-04, -6.08856684e-04],
#                 [ 2.31217930e-04,  1.83242788e-04,  7.90259325e-04, ...,
#                  -7.20376287e-05,  1.31608810e-04,  8.11118458e-04],
#                 [-1.75770694e-04,  1.00239541e-04, -1.20872472e-03, ...,
#                   5.78795319e-05,  6.53788122e-05, -3.40728723e-04]])

# %%
from matplotlib import gridspec

# Set up the figure with gridspec
fig = plt.figure(figsize=(12, 8))
gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1], wspace=0.3)

# Scatter plot on the left
ax_scatter = fig.add_subplot(gs[0])
ax_scatter.set_title(f'Fraction excited: {round(fraction_excitation0, 1)}%')

ax_scatter.scatter(x[turn], delta[turn], label="All particles")
ax_scatter.scatter(x[turn][excited0], delta[turn][excited0], label="Excited particles")
# ax_scatter.axvline(laser_x, color='red', linestyle='--', label="Laser position")

ax_scatter.set_xlabel('x [mm]')
ax_scatter.set_ylabel('dp/p')
ax_scatter.legend()
ax_scatter.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))

# Histogram on the right
ax_hist = fig.add_subplot(gs[1], sharey=ax_scatter)
#ax_hist.hist(x[turn], bins=30, orientation='horizontal', color='gray', alpha=0.7, label="x distribution")
ax_hist.hist(delta[turn][excited0], bins=30, orientation='horizontal', color='blue', alpha=0.7, label="Excited distribution")

ax_hist.set_xlabel('Counts')
ax_hist.legend()

# Match the y-limits of the scatter plot and histogram
y_min, y_max = ax_scatter.get_ylim()
ax_hist.set_ylim(y_min, y_max)

plt.tight_layout()
plt.show()
# Out:
# /tmp/pkruyt/ipykernel_19130/1566307986.py:32: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
hbar = 1.054571817e-34#; // J*sec
QELEM = 1.60217663e-19  # Elementary charge in Coulombs

# Perform the calculations with the updated parameters from notebook
w0 = laser_waist_radius
# w0= 1e-3
laser_energy = laser_energy
laser_sigma_t = sigma_t
laser_wavelength = lambda_l
ion_excited_lifetime = ion_excited_lifetime
ion_excitation_energy = hw0
#p0c = p0c
#m0 = mass0


beta=beta0

# Compute maximum laser intensity (I0)
I0 = (np.sqrt(2 / np.pi) * laser_energy / laser_sigma_t) / (np.pi * w0**2)  # W/m^2

# Rabi frequency calculation for the reference particle
OmegaRabi = (hbar*clight/(ion_excitation_energy*QELEM)) * \
            np.sqrt(I0*2*np.pi/(ion_excitation_energy*QELEM*ion_excited_lifetime))

# Calculate OmegaRabi * laser_sigma_t / (2 * gamma) for comparison
OmegaRabiTau = OmegaRabi * laser_sigma_t / (2 * gamma0)

# %%
print('OmegaRabi    =',OmegaRabi)
print('OmegaRabiTau =',OmegaRabiTau)
print('I0           =',I0)
# Out:
# OmegaRabi    = 8175161039376.016
# OmegaRabiTau = 1.018065097179791
# I0           = 85434994445260.03

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# Load data from the JSON file
with open('pulsed_excitation_map.json', 'r') as f:
    data = json.load(f)

# Extract the data from the JSON structure
Delta_max = data['Delta_detuning*tau_pulse max']
Omega_max = data['OmegaRabi*tau_pulse max']
Excitation = np.array(data['Excitation probability'])

# Generate the heatmap plot
plt.figure(figsize=(10, 6))
heatmap = plt.imshow(
    Excitation,
    extent=[0, Delta_max, 0, Omega_max],
    origin='lower',
    cmap='viridis',
    aspect='auto',
    vmin=0,
    vmax=1
)
plt.colorbar(heatmap)
plt.axhline(OmegaRabiTau,color='red')
plt.xlabel(r"$\Delta_d\tau_p$")
plt.ylabel(r"$\Omega_R\tau_p$")
plt.title("Excitation Probability Heatmap")
plt.grid(True)
plt.show()
